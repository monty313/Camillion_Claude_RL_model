# %% [markdown]
# # Camillion Claude RL Model — One-Click Train
#
# Beginner-friendly. Run the cells top to bottom. **Phase 0** wires steps 1–3 and a
# test cell; steps 4–9 are placeholders until Phases 1–2 land.

# %% [markdown]
# ## 1. Mount Google Drive  (price data + saved models live here)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Your MT5 data / cache folder, e.g. /content/drive/MyDrive/camillion-data

# %% [markdown]
# ## 2. Clone the repo

# %%
# !git clone https://github.com/monty313/Camillion_Claude_RL_model.git
# %cd Camillion_Claude_RL_model

# %% [markdown]
# ## 3. Install dependencies
# Phase-0 core is just numpy/pandas + pytest. TA-Lib (indicators) and torch/SB3
# (training) are installed in Phase 1.

# %%
# !pip -q install numpy pandas pytest
# Phase 1: !apt-get -y install ta-lib && pip -q install TA-Lib pyarrow gymnasium stable-baselines3 torch

# %% [markdown]
# ## ✅ Run the test suite (verifies the locked 357 observation contract)

# %%
# !pytest -q  ||  !python tools/run_tests.py

# %% [markdown]
# ## 4. Load cached data  *(Phase 1)*

# %%
# from src.data.cache_builder import build_cache  # Phase 1

# %% [markdown]
# ## 5. Precompute indicators → float32 cache  *(Phase 1)*

# %%
# build_cache(symbols=..., timeframes=...)  # Phase 1: parquet/memmap

# %% [markdown]
# ## 6. Train  *(Phase 1)*

# %%
# from src.training.trainer import train; train(...)  # Phase 1: PPO, fast

# %% [markdown]
# ## 7. Open Barbershop  *(Phase 2)*

# %%
# streamlit run src/jarvis/app.py   # Jarvis + Barbershop dashboard (Phase 2)

# %% [markdown]
# ## 8. Save model  *(Phase 1)*

# %%
# model.save('/content/drive/MyDrive/camillion-data/model.zip')  # Phase 1

# %% [markdown]
# ## 9. Resume  *(Phase 1)*

# %%
# from src.training.trainer import resume; resume('.../model.zip')  # Phase 1
